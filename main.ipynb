# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Data-Telur.csv",parse_dates=["Tgl"],date_parser=pd.to_datetime)
df.head()
# Out:
#          Tgl  Pagi  Sore  Jumlah  pecah   Dos  butir  Kirim  Sisa
# 0 2019-01-01   745   786    1531     21   NaN    NaN      0  2700
# 1 2019-01-02   575   952    1527     23   NaN    NaN      0  4204
# 2 2019-01-03   669   867    1536     20   NaN    NaN      0  5720
# 3 2019-01-04   669   859    1528     23  46.0  150.0   6900   325
# 4 2019-01-05   632   907    1539     22   NaN    NaN      0  1842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tgl     731 non-null    datetime64[ns]
#  1   Pagi    731 non-null    int64
#  2   Sore    731 non-null    int64
#  3   Jumlah  731 non-null    int64
#  4   pecah   731 non-null    int64
#  5   Dos     236 non-null    float64
#  6   butir   236 non-null    float64
#  7   Kirim   731 non-null    int64
#  8   Sisa    731 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(6)
# memory usage: 51.5 KB

# %%
df.isna().sum()
# Out:
# Tgl         0
# Pagi        0
# Sore        0
# Jumlah      0
# pecah       0
# Dos       495
# butir     495
# Kirim       0
# Sisa        0
# dtype: int64

# %%
df.fillna(0,inplace=True)
df.head(5)
# Out:
#          Tgl  Pagi  Sore  Jumlah  pecah   Dos  butir  Kirim  Sisa
# 0 2019-01-01   745   786    1531     21   0.0    0.0      0  2700
# 1 2019-01-02   575   952    1527     23   0.0    0.0      0  4204
# 2 2019-01-03   669   867    1536     20   0.0    0.0      0  5720
# 3 2019-01-04   669   859    1528     23  46.0  150.0   6900   325
# 4 2019-01-05   632   907    1539     22   0.0    0.0      0  1842

# %%
df.describe()
# Out:
#               Pagi         Sore       Jumlah       pecah        Dos  \
# count   731.000000   731.000000   731.000000  731.000000  731.00000
# mean   1020.600547  1017.900137  2038.480164   20.417237   11.47606
# std     112.626850   132.824138   198.685380    2.426380   19.82341
# min     575.000000   682.000000  1527.000000   10.000000    0.00000
# 25%     938.500000   919.000000  1904.000000   19.000000    0.00000
# 50%    1039.000000  1038.000000  2059.000000   21.000000    0.00000
# 75%    1106.500000  1107.500000  2176.000000   22.000000   27.50000
# max    1339.000000  1402.000000  2564.000000   28.000000   87.00000
#
#              butir         Kirim          Sisa
# count   731.000000    731.000000    731.000000
# mean    142.693570   1815.675787   3392.281806
# std     428.910805   2950.417608   2337.905149
# min       0.000000      0.000000   -529.000000
# 25%       0.000000      0.000000   1908.500000
# 50%       0.000000      0.000000   3275.000000
# ...

# %%
df[df.Sisa < 0]
# Out:
#            Tgl  Pagi  Sore  Jumlah  pecah   Dos  butir  Kirim  Sisa
# 496 2020-05-11  1136   978    2114     21  38.0  150.0   5700  -529
# 497 2020-05-12  1124  1008    2132     22   0.0    0.0      0  -169

# %%
dfcopy = df.copy()
df.drop(columns=['Kirim','butir','Dos','pecah','Sisa'], inplace=True)
df.head()
# Out:
#          Tgl  Pagi  Sore  Jumlah
# 0 2019-01-01   745   786    1531
# 1 2019-01-02   575   952    1527
# 2 2019-01-03   669   867    1536
# 3 2019-01-04   669   859    1528
# 4 2019-01-05   632   907    1539

# %%
sns.heatmap(data=df.corr(),annot=True,cmap="Blues",vmin=-1,vmax=1,linewidths=2)
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,8))
plt.plot(df.Tgl,df.Pagi)
plt.plot(df.Tgl,df.Sore)
plt.legend(["Pagi","Sore"])
plt.xticks(df["Tgl"][::180])
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(df.Tgl,df.Pagi)
plt.xticks(df["Tgl"][::180])
plt.show()
